# %% [markdown]
# <a href="https://colab.research.google.com/github/pranaya-08/CodeAlpha_project_Hangman/blob/main/hangman_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
stages = ["""
    -----
    |   |
    O   |
   /|\  |
   / \  |
        |
---------
""","""
    -----
    |   |
    O   |
   /|\  |
   /    |
        |
---------
""","""
    -----
    |   |
    O   |
   /|\  |
        |
        |
---------
""","""
    -----
    |   |
    O   |
   /|   |
        |
        |
---------
""","""
    -----
    |   |
    O   |
   /    |
        |
        |
---------
""","""
    -----
    |   |
    O   |
        |
        |
        |
---------
""","""
    -----
    |   |
        |
        |
        |
        |
---------
"""
]
word_list=["apple","beautiful","potato"]
lives=6
chosen_word=random.choice(word_list)
print(chosen_word)
display=[]
for i in range(len(chosen_word)):
    display += '_'
print(display)
game_over=False
while not game_over:
    guessed_letter=input("Guess a letter: ").lower()
    for position in range(len(chosen_word)):
        letter = chosen_word[position]
        if letter==guessed_letter:
            display[position]= guessed_letter
    print(display)
    if guessed_letter not in chosen_word:
        lives -= 1
        if lives == 0:
            game_over = True
            print("You lose!!")
    if '_' not in display:
        game_over=True
        print("You win !!")
    print(stages[lives])
# Out:
# apple
# ['_', '_', '_', '_', '_']
# Guess a letter: a
# ['a', '_', '_', '_', '_']
#
#     -----
#     |   |
#         |
#         |
#         |
#         |
# ---------
#
# Guess a letter: p
# ['a', 'p', 'p', '_', '_']
#
#     -----
#     |   |
#         |
#         |
#         |
#         |
# ---------
#
# Guess a letter: t
# ['a', 'p', 'p', '_', '_']
#
#     -----
#     |   |
#     O   |
#         |
#         |
#         |
# ---------
#
# Guess a letter: u
# ['a', 'p', 'p', '_', '_']
#
#     -----
#     |   |
#     O   |
#    /    |
#         |
#         |
# ---------
#
# Guess a letter: y
# ['a', 'p', 'p', '_', '_']
#
#     -----
#     |   |
#     O   |
#    /|   |
#         |
#         |
# ---------
#
# Guess a letter: w
# ['a', 'p', 'p', '_', '_']
#
#     -----
#     |   |
#     O   |
#    /|\  |
#         |
#         |
# ---------
#
# Guess a letter: o
# ['a', 'p', 'p', '_', '_']
#
#     -----
#     |   |
#     O   |
#    /|\  |
#    /    |
#         |
# ---------
#
# ...
